# %%
#Check Loan Eligibility
income = float(input("Enter your monthly income: ₹"))
expenses = float(input("Enter your monthly expenses: ₹"))

savings = income - expenses

if savings >= 10000:
    print("You are eligible for a loan.")
else:
    print("You are not eligible for a loan.")
# Out:
# Enter your monthly income: ₹ 50000
# Enter your monthly expenses: ₹ 20000
# You are eligible for a loan.

# %%
#Compound Interest Calculator
# Compound Interest = P(1 + R/100)^T - P
P = float(input("Enter Principal Amount: ₹"))
R = float(input("Enter Annual Interest Rate (%): "))
T = float(input("Enter Time (years): "))
N = int(input("Compounded times per year: "))

amount = P * (1 + R/(100*N))**(N*T)
ci = amount - P

print(f"Compound Interest: ₹{round(ci, 2)}")
print(f"Total Amount after {T} years: ₹{round(amount, 2)}")
# Out:
# Enter Principal Amount: ₹ 80000
# Enter Annual Interest Rate (%):  2
# Enter Time (years):  3
# Compounded times per year:  3
# Compound Interest: ₹4930.01
# Total Amount after 3.0 years: ₹84930.01

# %%
#deposit Money
balance = 1000
deposit = int(input("Enter amount to deposit: ₹"))
balance += deposit
print("New balance: ₹", balance)
# Out:
# Enter amount to deposit: ₹ 200
# New balance: ₹ 1200

# %%
#Withdraw Money
balance = 1000
withdraw = int(input("Enter amount to withdraw: ₹"))

if withdraw <= balance:
    balance -= withdraw
    print("Withdrawal successful. Balance: ₹", balance)
else:
    print("Insufficient balance!")
# Out:
# Enter amount to withdraw: ₹ 120
# Withdrawal successful. Balance: ₹ 880

# %%
#PIN Checking
pin = "1234"
user_pin = input("Enter your PIN")

if user_pin == pin:
    print("Access granted")
else:
    print("Incorrect PIN")
# Out:
# Enter your PIN 1234
# Access granted
